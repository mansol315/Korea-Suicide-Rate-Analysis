# %%
import pandas as pd

# %%
# CSV 파일 경로
file_path = 'C:/Users/ebg13/OneDrive/바탕 화면/시도별_정신건강관련기관.csv'

# %%
# CSV 파일 읽기
df = pd.read_csv(file_path, encoding='cp949')

# %%
df
# Out:
#       시도별(1)    시점   전체
# 0      서울특별시  2018  578
# 1      서울특별시  2019  637
# 2      서울특별시  2020  680
# 3      서울특별시  2021  726
# 4      서울특별시  2022  758
# ..       ...   ...  ...
# 97   제주특별자치도  2019   38
# 98   제주특별자치도  2020   38
# 99   제주특별자치도  2021   38
# 100  제주특별자치도  2022   42
# 101  제주특별자치도  2023   44
#
# [102 rows x 3 columns]

# %%
# 열 이름 확인 (원래 이름)
print("원래 열 이름:", df.columns.tolist())
# Out:
# 원래 열 이름: ['시도별(1)', '시점', '전체']

# %%
# 열 이름 변경
df.rename(columns={
    df.columns[0]: '시도',
    df.columns[1]: '연도',
    df.columns[2]: '정신건강관련기관수'
}, inplace=True)

# %%
df_cleaned = df.dropna()

# %%
df
# Out:
#           시도    연도  정신건강관련기관수
# 0      서울특별시  2018        578
# 1      서울특별시  2019        637
# 2      서울특별시  2020        680
# 3      서울특별시  2021        726
# 4      서울특별시  2022        758
# ..       ...   ...        ...
# 97   제주특별자치도  2019         38
# 98   제주특별자치도  2020         38
# 99   제주특별자치도  2021         38
# 100  제주특별자치도  2022         42
# 101  제주특별자치도  2023         44
#
# [102 rows x 3 columns]

# %%
df.to_csv('C:/Users/ebg13/OneDrive/바탕 화면/시도별_정신건강관련기관_전처리.csv', index=False)
