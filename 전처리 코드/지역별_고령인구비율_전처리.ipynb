# %%
import pandas as pd

# %%
# CSV 파일 경로
file_path = 'C:/Users/ebg13/OneDrive/바탕 화면/시도별_고령인구비율.csv'

# %%
# CSV 파일 읽기
df = pd.read_csv(file_path, encoding='cp949')

# %%
df
# Out:
#     행정구역별(1)    시점  고령인구비율<br>(A÷B×100) (%)
# 0      서울특별시  2018                     14.4
# 1      서울특별시  2019                     15.2
# 2      서울특별시  2020                     16.1
# 3      서울특별시  2021                     16.8
# 4      서울특별시  2022                     17.6
# ..       ...   ...                      ...
# 97   제주특별자치도  2019                     15.0
# 98   제주특별자치도  2020                     15.7
# 99   제주특별자치도  2021                     16.3
# 100  제주특별자치도  2022                     17.1
# 101  제주특별자치도  2023                     17.9
#
# [102 rows x 3 columns]

# %%
# 열 이름 확인 (원래 이름)
print("원래 열 이름:", df.columns.tolist())
# Out:
# 원래 열 이름: ['행정구역별(1)', '시점', '고령인구비율<br>(A÷B×100) (%)']

# %%
# 열 이름 변경
df.rename(columns={
    df.columns[0]: '시도',
    df.columns[1]: '연도',
    df.columns[2]: '고령인구비율'
}, inplace=True)

# %%
df_cleaned = df.dropna()

# %%
df
# Out:
#           시도    연도  고령인구비율
# 0      서울특별시  2018    14.4
# 1      서울특별시  2019    15.2
# 2      서울특별시  2020    16.1
# 3      서울특별시  2021    16.8
# 4      서울특별시  2022    17.6
# ..       ...   ...     ...
# 97   제주특별자치도  2019    15.0
# 98   제주특별자치도  2020    15.7
# 99   제주특별자치도  2021    16.3
# 100  제주특별자치도  2022    17.1
# 101  제주특별자치도  2023    17.9
#
# [102 rows x 3 columns]

# %%
df.to_csv('C:/Users/ebg13/OneDrive/바탕 화면/시도별_고령인구비율_전처리.csv', index=False)
